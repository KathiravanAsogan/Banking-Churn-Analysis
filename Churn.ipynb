# %%
import numpy as np 
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Importing dataset from my computer
# # This data sourced from Kaggle

# %%
df=pd.read_csv("/Users/kathirsurya/Desktop/My Codes/Kaggle Datasets/Churn Modelling.csv")

# %% [markdown]
# # Checking the first 5 rows from the dataset

# %%
df.head(10)
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
# 5          6    15574012       Chu          645     Spain    Male   44
# 6          7    15592531  Bartlett          822    France    Male   50
# 7          8    15656148    Obinna          376   Germany  Female   29
# 8          9    15792365        He          501    France    Male   44
# 9         10    15592389        H?          684    France    Male   27
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# ...

# %% [markdown]
# # Checking the random rows from the dataset

# %%
df.sample(10)
# Out:
#       RowNumber  CustomerId     Surname  CreditScore Geography  Gender  Age  \
# 103         104    15776605     Bradley          528     Spain    Male   36
# 8028       8029    15775124  Watterston          763     Spain    Male   37
# 5911       5912    15697567    Bazarova          752    France    Male   33
# 2418       2419    15603914      Arcuri          614    France    Male   40
# 8476       8477    15603082     Yashina          701    France    Male   51
# 5555       5556    15572398    Townsend          614     Spain  Female   39
# 923         924    15601026   Gallagher          572   Germany  Female   19
# 6862       6863    15736287      Piccio          586    France    Male   33
# 6438       6439    15647974   Chiemenam          679    France  Female   44
# 5734       5735    15596647   Henderson          768    France    Male   54
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %% [markdown]
# # How big is this data?

# %%
df.shape
# Out:
# (10000, 14)

# %% [markdown]
# # What are the data types ?

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# # How this data looks mathematically?

# %%
df.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %% [markdown]
# # Null Values

# %%
df.isnull().sum()
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# # Duplicate Values

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
As the following columns are not useful for the prediction or analysis, removing those 

01. Rownumber 
02. CustomerId 
03. Surname

# %%
df=df.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)

# %%
df.head()
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0          1               1        101348.88       1
# 1          0               1        112542.58       0
# 2          1               0        113931.57       1
# 3          0               0         93826.63       0
# 4          1               1         79084.10       0

# %%
print(df.columns)
# Out:
# Index(['CreditScore', 'Geography', 'Gender', 'Age', 'Tenure', 'Balance',
#        'NumOfProducts', 'HasCrCard', 'IsActiveMember', 'EstimatedSalary',
#        'Exited'],
#       dtype='str')

# %% [markdown]
# # Univariate Analysis
# - Analyzing one variable

# %% [markdown]
# # Analyzing Gender Variable

# %%
ax=sns.countplot(data=df, x='Gender')

ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '4543'), Text(0, 0, '5457')]

# %% [markdown]
# # Analyzing Geography Variable

# %%
ax=sns.countplot(data=df,x='Geography')
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '5014'), Text(0, 0, '2477'), Text(0, 0, '2509')]

# %% [markdown]
# # Analyzing NoOfProducts

# %%
ax=sns.countplot(data=df,x='NumOfProducts')
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '5084'), Text(0, 0, '4590'), Text(0, 0, '266'), Text(0, 0, '60')]

# %% [markdown]
# # Analyzing the HasCrCard variable

# %%
ax=sns.countplot(data=df, x='HasCrCard')
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '2945'), Text(0, 0, '7055')]

# %% [markdown]
# # Analyzing the IsActiveMember variable

# %%
ax=sns.countplot(data=df, x='IsActiveMember')
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '4849'), Text(0, 0, '5151')]

# %% [markdown]
# # Analyzing the Exited Variable

# %%
ax=sns.countplot(data=df, x='Exited')
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '7963'), Text(0, 0, '2037')]

# %% [markdown]
# # BiVariate Analysis
# - Analyzing two variables

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x='Exited', y='Age', data=df)

plt.title('Age Vs Exited')
plt.show()
